# %% [markdown]
# ### Packages

# %%
# !python --version
# Out:
# Python 3.10.19

# %%
# !pip install py4j pandas pyarrow
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\roaming\python\python310\site-packages)
# ...

# %% [markdown]
# ### Working with anaconda prompt

# %% [markdown]
# ![Spark using cmd](images/Screenshot 2025-11-18 090152- intro.png)
